# %%
import os
os.getcwd()
# Out:
# '/Users/mac/Downloads/data_analytics_portfolio'

# %%
import pandas as pd
Df= pd.read_excel("cancer patient data sets.xlsx")
import matplotlib.pyplot as plt

Df_clean = Df.copy()
Df_clean.columns= Df_clean.columns.str.strip().str.lower().str.replace(' ' , '_')
Df_clean
# Out:
#     patient_id  age  gender  air_pollution  alcohol_use  dust_allergy  \
# 0           P1   33       1              2            4             5
# 1          P10   17       1              3            1             5
# 2         P100   35       1              4            5             6
# 3        P1000   37       1              7            7             7
# 4         P101   46       1              6            8             7
# ..         ...  ...     ...            ...          ...           ...
# 995       P995   44       1              6            7             7
# 996       P996   37       2              6            8             7
# 997       P997   25       2              4            5             6
# 998       P998   18       2              6            8             7
# 999       P999   47       1              6            5             6
#
#      occupational_hazards  genetic_risk  chronic_lung_disease  balanced_diet  \
# ...

# %%
Df_clean.head(20)
# Out:
#    patient_id  age  gender  air_pollution  alcohol_use  dust_allergy  \
# 0          P1   33       1              2            4             5
# 1         P10   17       1              3            1             5
# 2        P100   35       1              4            5             6
# 3       P1000   37       1              7            7             7
# 4        P101   46       1              6            8             7
# 5        P102   35       1              4            5             6
# 6        P103   52       2              2            4             5
# 7        P104   28       2              3            1             4
# 8        P105   35       2              4            5             6
# 9        P106   46       1              2            3             4
# 10       P107   44       1              6            7             7
# 11       P108   64       2              6            8             7
# 12       P109   39       2              4            5             6
# ...

# %%
Df_clean.tail()
# Out:
#     patient_id  age  gender  air_pollution  alcohol_use  dust_allergy  \
# 995       P995   44       1              6            7             7
# 996       P996   37       2              6            8             7
# 997       P997   25       2              4            5             6
# 998       P998   18       2              6            8             7
# 999       P999   47       1              6            5             6
#
#      occupational_hazards  genetic_risk  chronic_lung_disease  balanced_diet  \
# 995                     7             7                     6              7
# 996                     7             7                     6              7
# 997                     5             5                     4              6
# 998                     7             7                     6              7
# 999                     5             5                     4              6
#
#      ...  fatigue  weight_loss  shortness_of_breath  wheezing  \
# ...

# %%
Df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 25 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   patient_id                1000 non-null   object
#  1   age                       1000 non-null   int64
#  2   gender                    1000 non-null   int64
#  3   air_pollution             1000 non-null   int64
#  4   alcohol_use               1000 non-null   int64
#  5   dust_allergy              1000 non-null   int64
#  6   occupational_hazards      1000 non-null   int64
#  7   genetic_risk              1000 non-null   int64
#  8   chronic_lung_disease      1000 non-null   int64
#  9   balanced_diet             1000 non-null   int64
#  10  obesity                   1000 non-null   int64
#  11  smoking                   1000 non-null   int64
#  12  passive_smoker            1000 non-null   int64
#  13  chest_pain                1000 non-null   int64
# ...

# %%
Df_clean.isnull().sum()
# Out:
# patient_id                  0
# age                         0
# gender                      0
# air_pollution               0
# alcohol_use                 0
# dust_allergy                0
# occupational_hazards        0
# genetic_risk                0
# chronic_lung_disease        0
# balanced_diet               0
# obesity                     0
# smoking                     0
# passive_smoker              0
# chest_pain                  0
# coughing_of_blood           0
# fatigue                     0
# weight_loss                 0
# shortness_of_breath         0
# wheezing                    0
# swallowing_difficulty       0
# clubbing_of_finger_nails    0
# frequent_cold               0
# dry_cough                   0
# snoring                     0
# level                       0
# dtype: int64

# %%
Df_clean.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# how many patients are at different cancer levels (low,medium,high)

# %%
Df_clean['level'].value_counts()
# Out:
# level
# High      365
# Medium    332
# Low       303
# Name: count, dtype: int64

# %%
Dataframe['Gender'].value_counts()

# %%
Dataframe = Df_clean.sort_values('age', ascending=True)
Dataframe
# Out:
#     patient_id  age  gender  air_pollution  alcohol_use  dust_allergy  \
# 907       P915   14       1              2            4             5
# 574       P615   14       1              2            4             5
# 685       P715   14       1              2            4             5
# 130       P215   14       1              2            4             5
# 352       P415   14       1              2            4             5
# ..         ...  ...     ...            ...          ...           ...
# 348       P411   73       1              5            6             6
# 889         P9   73       1              5            6             6
# 903       P911   73       1              5            6             6
# 126       P211   73       1              5            6             6
# 15        P111   73       1              5            6             6
#
#      occupational_hazards  genetic_risk  chronic_lung_disease  balanced_diet  \
# ...

# %%
Df_clean['age'].mean()
# Out:
# np.float64(37.174)

# %%
Df_clean['age'].max()
# Out:
# np.int64(73)

# %%
Dataframe.groupby('Gender')['Level']

# %%
Df_clean.describe()
# Out:
#                age       gender  air_pollution  alcohol_use  dust_allergy  \
# count  1000.000000  1000.000000      1000.0000  1000.000000   1000.000000
# mean     37.174000     1.402000         3.8400     4.563000      5.165000
# std      12.005493     0.490547         2.0304     2.620477      1.980833
# min      14.000000     1.000000         1.0000     1.000000      1.000000
# 25%      27.750000     1.000000         2.0000     2.000000      4.000000
# 50%      36.000000     1.000000         3.0000     5.000000      6.000000
# 75%      45.000000     2.000000         6.0000     7.000000      7.000000
# max      73.000000     2.000000         8.0000     8.000000      8.000000
#
#        occupational_hazards  genetic_risk  chronic_lung_disease  \
# count           1000.000000   1000.000000           1000.000000
# mean               4.840000      4.580000              4.380000
# std                2.107805      2.126999              1.848518
# ...

# %%
Df_clean['gender_label'] = Df_clean['gender'].map({1:'male' ,2 :'female'})
Df_clean
# Out:
#     patient_id  age  gender  air_pollution  alcohol_use  dust_allergy  \
# 0           P1   33       1              2            4             5
# 1          P10   17       1              3            1             5
# 2         P100   35       1              4            5             6
# 3        P1000   37       1              7            7             7
# 4         P101   46       1              6            8             7
# ..         ...  ...     ...            ...          ...           ...
# 995       P995   44       1              6            7             7
# 996       P996   37       2              6            8             7
# 997       P997   25       2              4            5             6
# 998       P998   18       2              6            8             7
# 999       P999   47       1              6            5             6
#
#      occupational_hazards  genetic_risk  chronic_lung_disease  balanced_diet  \
# ...

# %%
risk_factors = ["air_pollution","alcohol_use","dust_allergy","occupational_hazards","genetic_risk","balanced_diet","frequent_cold"]
risk_factors
# Out:
# ['air_pollution',
#  'alcohol_use',
#  'dust_allergy',
#  'occupational_hazards',
#  'genetic_risk',
#  'balanced_diet',
#  'frequent_cold']

# %%
gender_risk=Df_clean.groupby('gender_label')[risk_factors].mean()
gender_risk
# Out:
#               air_pollution  alcohol_use  dust_allergy  occupational_hazards  \
# gender_label
# female             3.228856     3.835821      4.671642              4.345771
# male               4.250836     5.051839      5.496656              5.172241
#
#               genetic_risk  balanced_diet  frequent_cold
# gender_label
# female            4.002488       4.231343       3.534826
# male              4.968227       4.665552       3.536789

# %%
Df_clean.groupby("gender_label")['level'].value_counts()
# Out:
# gender_label  level
# female        Low       154
#               Medium    135
#               High      113
# male          High      252
#               Medium    197
#               Low       149
# Name: count, dtype: int64

# %%
Df_clean['gender_label'].value_counts()
# Out:
# gender_label
# male      598
# female    402
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
gender_risk.plot(
    kind="bar",
    figsize=(12,7),  
    title ="cancer risks on genders")


plt.ylabel('Average Score')   # label y axis
plt.xticks(rotation=0)        # keep gender labels straight
plt.legend(loc='upper right' ,bbox_to_anchor=( 1,1)) # show column legend
plt.tight_layout()            # prevents labels cutting off
plt.show()

# %%
Df_clean["age"].min()
# Out:
# np.int64(14)

# %%
Df_clean.groupby('level')["age"].mean()
# Out:
# level
# High      37.320548
# Low       35.412541
# Medium    38.620482
# Name: age, dtype: float64

# %%
Df_clean.groupby('level')['age'].value_counts()
# Out:
# level   age
# High    37     50
#         33     29
#         35     29
#         26     26
#         44     20
#                ..
# Medium  36      9
#         24      1
#         26      1
#         37      1
#         51      1
# Name: count, Length: 76, dtype: int64

# %% [markdown]
# are younger patients getting higher risk diagnose

# %%
young=Df_clean[Df_clean['age']<30]
young
# Out:
#     patient_id  age  gender  air_pollution  alcohol_use  dust_allergy  \
# 1          P10   17       1              3            1             5
# 7         P104   28       2              3            1             4
# 14        P110   27       2              3            1             4
# 16        P112   17       1              3            1             5
# 19        P115   14       1              2            4             5
# ..         ...  ...     ...            ...          ...           ...
# 986       P987   19       1              6            8             7
# 987       P988   29       2              4            5             6
# 992       P992   26       2              7            7             7
# 997       P997   25       2              4            5             6
# 998       P998   18       2              6            8             7
#
#      occupational_hazards  genetic_risk  chronic_lung_disease  balanced_diet  \
# ...

# %%
young['level'].value_counts()
# Out:
# level
# Low       128
# High      104
# Medium     69
# Name: count, dtype: int64

# %%
young_high=Df_clean[(Df_clean['age']<30)& (Df_clean['level'] == 'High')]
young_high[risk_factors].mean()
# Out:
# air_pollution           5.894231
# alcohol_use             7.009615
# dust_allergy            6.817308
# occupational_hazards    6.634615
# genetic_risk            6.461538
# balanced_diet           6.817308
# frequent_cold           3.596154
# dtype: float64

# %% [markdown]
# which symptoms predict cancer levels?

# %%
symptoms = ['fatigue','weight_loss','shortness_of_breath','wheezing','swallowing_diffigculty', 'chest_pain','coughing_of_blood']
Df_clean.groupby('level')[symptoms].mean()
# Out:
#          fatigue  weight_loss  shortness_of_breath  wheezing  \
# level
# High    5.589041     4.468493             5.328767  3.884932
# Low     2.171617     2.501650             2.498350  2.574257
# Medium  3.487952     4.415663             4.632530  4.756024
#
#         swallowing_difficulty  chest_pain  coughing_of_blood
# level
# High                 4.189041    6.391781           7.438356
# Low                  2.759076    2.834983           2.861386
# Medium               4.159639    3.753012           3.846386

# %%
high_risk = Df_clean[Df_clean['level']== 'High']
high_risk[risk_factors].mean().sort_values(ascending=False)
# Out:
# alcohol_use             6.830137
# balanced_diet           6.619178
# dust_allergy            6.616438
# occupational_hazards    6.479452
# genetic_risk            6.375342
# air_pollution           5.693151
# frequent_cold           4.380822
# dtype: float64
